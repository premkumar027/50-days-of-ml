# %% [markdown]
# ## 🌐 Fetching Data from an API (TMDB Example)
#
# Here's a step-by-step guide to practicing with **The Movie Database (TMDB) API**:
#
# ---
#
# ### 🧭 Step-by-Step Instructions
#
# 1. Visit the official **TMDB API** website:
#    👉 [https://developer.themoviedb.org](https://developer.themoviedb.org)
#
# 2. Go to the **API Reference** section
#
# 3. From the left-hand navigation, click on **"Movies"**
#
# 4. Copy one of the sample code snippets (e.g., for Discover or Search APIs)
#
# ---
#
# ### 🔑 Get Your API Key
#
# 1. Create an account at: [https://www.themoviedb.org](https://www.themoviedb.org)
# 2. After logging in, go to: profile > API > copy API KEY
#
# ---
#
# ### 🧪 Add Your API Key to the Code
#
# In the copied code snippet, paste your API key at the end of the URL like this:
# ```python
# &api_key=YOUR_API_KEY

# %%
import pandas as pd

# %%
# i get this code from the API page
import requests

url = "https://api.themoviedb.org/3/discover/movie?include_adult=false&include_video=false&language=en-US&page=500&sort_by=popularity.desc&api_key=dba3f57fd9ddde9dffaa181c3ca65ed7"

headers = {"accept": "application/json"}

response = requests.get(url, headers=headers)

print(response.text)
# Out:
# {"page":500,"results":[{"adult":false,"backdrop_path":"/uxQW0C3TkbasUJbShlFTnvaaZP4.jpg","genre_ids":[53,27],"id":18781,"original_language":"en","original_title":"The Haunting in Connecticut","overview":"When the Campbell family moves to upstate Connecticut, they soon learn that their charming Victorian home has a disturbing history: not only was the house a transformed funeral parlor where inconceivable acts occurred, but the owner's clairvoyant son Jonah served as a demonic messenger, providing a gateway for spiritual entities to crossover.","popularity":1.8097,"poster_path":"/qwBXiHCMmbqSiDCLQJnUwWWzx0X.jpg","release_date":"2009-03-27","title":"The Haunting in Connecticut","video":false,"vote_average":6.161,"vote_count":1129},{"adult":false,"backdrop_path":"/bMjSLynLefcVZ8vPsVHyQDdAvZF.jpg","genre_ids":[28,80,53],"id":629040,"original_language":"ar","original_title":"ولاد رزق 3: القاضية","overview":"Years have passed since the brothers have separated in their different ways of life. But one day, a ghost from the past returns to cast a shadow over the sons of Rizk, forcing them to return to a life of crime and theft once again in order to save themselves, in a fateful operation that is the largest, most dangerous, and most important in the history of the sons of Rizk.","popularity":1.8095,"poster_path":"/oYwTsy5sNz3TvIeYBWyDRYnTzdu.jpg","release_date":"2024-06-12","title":"Sons of Rizk 3: Knockout","video":false,"vote_average":7.091,"vote_count":11},{"adult":false,"backdrop_path":"/pmyt5PsQ82zZxzO6mzYPI2qiZHU.jpg","genre_ids":[35,10749],"id":401917,"original_language":"ja","original_title":"黒崎くんの言いなりになんてならない","overview":"Yū Akahane moves to a dormitory room after her father's transfer from work. She is excited that she will live in the same dorm as Takumi Shirakawa, aka \"White Prince.\" Yet, Haruto Kurosaki, aka \"Black Devil\", kisses her as punishment for going against him. It is Yū Akahane's first kiss. Since then, she becomes obedient to Haruto Kurosaki.","popularity":1.8095,"poster_path":"/aaBBzbDyqyBf2gjzqWdXSmgMlcj.jpg","release_date":"2016-02-27","title":"The Black Devil and the White Prince","video":false,"vote_average":7.583,"vote_count":102},{"adult":false,"backdrop_path":"/5f5Qh9tpxIaQK9EkHzZ4oYZmy4.jpg","genre_ids":[18,10749],"id":57575,"original_language":"en","original_title":"The Last Time I Saw Paris","overview":"Reporter Charles Wills, in Paris to cover the end of World War II, falls for the beautiful Helen Ellswirth following a brief flirtation with her sister, Marion. After he and Helen marry, Charles pursues his novelistic ambition while supporting his new bride with a deadening job at a newspaper wire service. But when an old investment suddenly makes the family wealthy, their marriage begins to unravel — until a sudden tragedy changes everything.","popularity":1.8094,"poster_path":"/rerbqTR085seifQjy7bpnEJJ9qI.jpg","release_date":"1954-11-18","title":"The Last Time I Saw Paris","video":false,"vote_average":6.036,"vote_count":56},{"adult":false,"backdrop_path":"/aVsq5KA3JfnDcee1tQhgiXtwBDP.jpg","genre_ids":[28,12,14,10751],"id":454294,"original_language":"en","original_title":"The Kid Who Would Be King","overview":"Old-school magic meets the modern world when young Alex stumbles upon the mythical sword Excalibur. He soon unites his friends and enemies, and they become knights who join forces with the legendary wizard Merlin. Together, they must save mankind from the wicked enchantress Morgana and her army of supernatural warriors.","popularity":1.8093,"poster_path":"/kBuvLX6zynQP0sjyqbXV4jNaZ4E.jpg","release_date":"2019-01-16","title":"The Kid Who Would Be King","video":false,"vote_average":6.201,"vote_count":792},{"adult":false,"backdrop_path":"/AwWMcB5lFPLe8nZVXrBqPdHQ26.jpg","genre_ids":[10751,35],"id":35169,"original_language":"en","original_title":"Furry Vengeance","overview":"When real estate developer Dan Sanders finalizes plans to level a swath of pristine Oregon forest to make way for a soulle ...

# %%
pd.DataFrame(response.json()['results'])[['adult', 'id', 'original_language', 'original_title', 'popularity', 'title', 'release_date']]
# Out:
#     adult       id original_language  \
# 0   False    18781                en
# 1   False   629040                ar
# 2   False   401917                ja
# 3   False    57575                en
# 4   False   454294                en
# 5   False    35169                en
# 6   False  1153291                es
# 7   False   500922                en
# 8   False   416724                en
# 9   False    14367                en
# 10  False      203                en
# 11  False   206277                en
# 12  False    11317                en
# 13  False     2755                en
# 14  False   566228                en
# 15  False    25016                en
# 16  False    57157                en
# 17  False    10375                en
# 18  False    11617                en
# 19  False   127651                en
#
#                                    original_title  popularity  \
# 0                     The Haunting in Connecticut      1.8097
# 1                             ولاد رزق 3: القاضية      1.8095
# 2                               黒崎くんの言いなりになんてならない      1.8095
# 3                       The Last Time I Saw Paris      1.8094
# 4                       The Kid Who Would Be King      1.8093
# 5                                 Furry Vengeance      1.8091
# 6                                 Llamada privada      1.8089
# 7                               A Score to Settle      1.8089
# 8                                            Boar      1.8089
# 9                       Adventures in Babysitting      1.8087
# 10                                   Mean Streets      1.8086
# 11                    Shirley: Visions of Reality      1.8085
# 12                                      My Girl 2      1.8085
# 13                                  About Schmidt      1.8083
# 14  The Inventor: Out for Blood in Silicon Valley      1.8082
# 15                                      Pygmalion      1.8082
# 16                                    Young Adult      1.8081
# 17                                          D-Tox      1.8079
# 18                                     Rio Grande      1.8078
# 19                            The Seasoning House      1.8074
#
#                                             title release_date
# 0                     The Haunting in Connecticut   2009-03-27
# 1                        Sons of Rizk 3: Knockout   2024-06-12
# 2            The Black Devil and the White Prince   2016-02-27
# 3                       The Last Time I Saw Paris   1954-11-18
# 4                       The Kid Who Would Be King   2019-01-16
# 5                                 Furry Vengeance   2010-04-30
# 6                                    Private call   2023-07-11
# 7                               A Score to Settle   2019-08-01
# 8                                            Boar   2018-06-17
# 9                       Adventures in Babysitting   1987-07-01
# 10                                   Mean Streets   1973-10-14
# 11                    Shirley: Visions of Reality   2013-12-26
# 12                                      My Girl 2   1994-02-11
# 13                                  About Schmidt   2002-12-12
# 14  The Inventor: Out for Blood in Silicon Valley   2019-01-24
# 15                                      Pygmalion   1939-03-03
# 16                                    Young Adult   2011-11-11
# 17                                          D-Tox   2002-01-04
# 18                                     Rio Grande   1950-11-15
# 19                            The Seasoning House   2012-08-21

# %% [markdown]
# ---
#
# ## 🔁 Fetching All Movie Data from TMDB (Multiple Pages)
#
# The API response only gives **one page at a time**, with each page containing ~20 movies.
#
# - The total number of pages in the JSON was: **500**
# - That means there are approximately **9000 movies**
# - To fetch all of them, we use a **for loop** that goes from page `1` to `500`
#
# This ensures we collect **all available movie data** instead of just the first page.
#
# ---

# %%
df_new = pd.DataFrame()

# %%
for i in range(1, 501):
    url = f"https://api.themoviedb.org/3/discover/movie?include_adult=false&include_video=false&language=en-US&page={i}&sort_by=popularity.desc&api_key=dba3f57fd9ddde9dffaa181c3ca65ed7"
    response = requests.get(url, headers=headers)
    df = pd.DataFrame(response.json()['results'])[['adult', 'id', 'original_language', 'original_title', 'popularity', 'title', 'release_date']]
    df_new = pd.concat([df, df_new], ignore_index=True)

# %%
df_new
# Out:
#       adult       id original_language                original_title  \
# 0     False    18781                en   The Haunting in Connecticut
# 1     False   629040                ar           ولاد رزق 3: القاضية
# 2     False   401917                ja             黒崎くんの言いなりになんてならない
# 3     False    57575                en     The Last Time I Saw Paris
# 4     False   454294                en     The Kid Who Would Be King
# ...     ...      ...               ...                           ...
# 9992  False   986056                en                 Thunderbolts*
# 9993  False   574475                en  Final Destination Bloodlines
# 9994  False  1374534                nl                     Bad Boa's
# 9995  False  1285965                en             Dangerous Animals
# 9996  False  1100988                en                28 Years Later
#
#       popularity                                 title release_date
# 0         1.8097           The Haunting in Connecticut   2009-03-27
# 1         1.8095              Sons of Rizk 3: Knockout   2024-06-12
# 2         1.8095  The Black Devil and the White Prince   2016-02-27
# 3         1.8094             The Last Time I Saw Paris   1954-11-18
# 4         1.8093             The Kid Who Would Be King   2019-01-16
# ...          ...                                   ...          ...
# 9992    202.8670                         Thunderbolts*   2025-04-30
# 9993    190.3476          Final Destination Bloodlines   2025-05-14
# 9994    182.5215                           Almost Cops   2025-07-10
# 9995    181.5288                     Dangerous Animals   2025-06-05
# 9996    162.5811                        28 Years Later   2025-06-18
#
# [9997 rows x 7 columns]

# %%
df_new.to_csv('movies_dataset.csv', index=False)
